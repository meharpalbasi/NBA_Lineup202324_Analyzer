# %%
from nba_api.stats.endpoints import teamdashlineups
import pandas as pd
import time

# %%
from nba_api.stats.static import teams
nba_teams = teams.get_teams()

# %%
team_dict = {}
for i in nba_teams:
    team_name = i['full_name']
    team_id = i['id']
    team_dict[team_name]= team_id

# %%
def get_lineups(team_id_i, retries=3, delay=2):
    import time
    
    for attempt in range(retries):
        try:
            lineup = teamdashlineups.TeamDashLineups(
                date_from_nullable = "",
                date_to_nullable = "",
                game_id_nullable = "",
                game_segment_nullable = "",
                group_quantity = 5,
                last_n_games = 0,
                league_id_nullable = "00",
                location_nullable = "",
                measure_type_detailed_defense = "Base",
                month = 0,
                opponent_team_id = 0,
                outcome_nullable = "",
                pace_adjust = "N",
                plus_minus = "N",
                po_round_nullable = "",
                per_mode_detailed = "Totals",
                period = 0,
                rank = "N",
                season = "2024-25",
                season_segment_nullable = "",
                season_type_all_star = "Regular Season",
                shot_clock_range_nullable = "",
                team_id = team_id_i,
                vs_conference_nullable = "",
                vs_division_nullable = ""
            )
            
            df = lineup.get_data_frames()
            all_lineups = df[1]
            return all_lineups
            
        except Exception as e:
            if attempt < retries - 1:  # if not last attempt
                time.sleep(delay)  # wait before retrying
                continue
            else:
                print(f"Failed to get data for team_id: {team_id_i}")
                print(f"Error: {str(e)}")
                return None

# %%
# Modified main loop
league_lineup = pd.DataFrame()

for i in team_dict:
    team_id_i = team_dict[i]
    team_lineup = get_lineups(team_id_i)
    
    if team_lineup is not None:
        team_lineup['team'] = i
        team_lineup['team_id'] = team_id_i
        league_lineup = pd.concat([league_lineup, team_lineup], ignore_index=True)
    
    time.sleep(1)  # Add delay between requests

# %%
league_lineup['players_list'] = league_lineup['GROUP_NAME'].str.split(' - ')
league_lineup = league_lineup.sort_values(by='team')
league_lineup.to_csv('NBALineup2024.csv')

# %%
# In[0]: Imports
from nba_api.stats.endpoints import teamdashlineups
from nba_api.stats.static import teams
import pandas as pd
import time

# In[1]: Get Team Information
nba_teams = teams.get_teams()

# In[2]: Create Team Dictionary
team_dict = {}
for i in nba_teams:
    team_name = i['full_name']
    team_id = i['id']
    team_dict[team_name]= team_id

# In[3]: Define Function to Get Lineups with Measure Type and Season Type
def get_lineups(team_id_i, measure_type="Base", season_type="Regular Season", season="2024-25", retries=3, delay=2):
    """
    Fetches lineup data for a specific team, measure type, season type, and season from the NBA API.

    Args:
        team_id_i (int): The ID of the team.
        measure_type (str): The type of stats to fetch (e.g., "Base", "Advanced").
        season_type (str): The type of season ("Regular Season" or "Playoffs").
        season (str): The season identifier (e.g., "2024-25").
        retries (int): Number of retry attempts in case of API errors.
        delay (int): Delay in seconds between retries.

    Returns:
        pandas.DataFrame or None: DataFrame containing lineup data or None if fetching fails.
    """
    import time # Ensure time is available

    print(f"    Fetching {season_type} - {measure_type} stats for team ID {team_id_i} (Season: {season})...") # More specific print

    for attempt in range(retries):
        try:
            lineup = teamdashlineups.TeamDashLineups(
                date_from_nullable = "",
                date_to_nullable = "",
                game_id_nullable = "",
                game_segment_nullable = "",
                group_quantity = 5,
                last_n_games = 0,
                league_id_nullable = "00",
                location_nullable = "",
                measure_type_detailed_defense = measure_type, # Use the function argument
                month = 0,
                opponent_team_id = 0,
                outcome_nullable = "",
                pace_adjust = "N",
                plus_minus = "N",
                po_round_nullable = "",
                per_mode_detailed = "Totals",
                period = 0,
                rank = "N",
                season = season, # Use season parameter
                season_segment_nullable = "",
                season_type_all_star = season_type, # Use season_type parameter
                shot_clock_range_nullable = "",
                team_id = team_id_i,
                vs_conference_nullable = "",
                vs_division_nullable = ""
            )

            df_list = lineup.get_data_frames()

            # The lineup data is typically the second DataFrame (index 1)
            if df_list and len(df_list) > 1:
                all_lineups = df_list[1]
                # Add the season type column right after fetching
                all_lineups['SEASON_TYPE'] = season_type
                print(f"      Successfully fetched {len(all_lineups)} rows.")
                return all_lineups
            else:
                 print(f"      Warning: Unexpected data structure returned. DataFrames received: {len(df_list) if df_list else 'None'}")
                 return None # Return None if structure is wrong

        except Exception as e:
            print(f"      Attempt {attempt + 1} failed. Error: {str(e)}")
            if attempt < retries - 1:  # if not last attempt
                print(f"      Retrying in {delay} seconds...")
                time.sleep(delay)  # wait before retrying
            else:
                print(f"      Failed to get data after {retries} attempts.")
                return None # Return None after all retries fail

# In[4]: Main Loop to Fetch, Merge, and Aggregate Data for Both Season Types
league_lineup = pd.DataFrame()
# Define the season types you want to fetch
season_types_to_fetch = ["Regular Season", "Playoffs"]
# Define the season year you are interested in
target_season = "2024-25" # Using a completed season to ensure playoff data exists

print(f"Starting data fetch for season: {target_season}")
print("-" * 30)

for team_name, team_id_i in team_dict.items():
    print(f"\nProcessing team: {team_name} ({team_id_i})")

    team_has_data = False # Flag to track if any data was added for this team

    for season_type in season_types_to_fetch:
        print(f"  Processing {season_type} data...")

        # Get Base stats for the current season type
        team_lineup_base = get_lineups(team_id_i,
                                       measure_type="Base",
                                       season_type=season_type,
                                       season=target_season)
        time.sleep(0.6) # API Rate limit consideration

        # Get Advanced stats for the current season type
        team_lineup_advanced = get_lineups(team_id_i,
                                           measure_type="Advanced",
                                           season_type=season_type,
                                           season=target_season)

        # --- Merging Logic ---
        merged_data_for_season_type = None # To hold the result for this season type

        if team_lineup_base is not None and not team_lineup_base.empty and \
           team_lineup_advanced is not None and not team_lineup_advanced.empty:

            print(f"    Merging Base and Advanced {season_type} stats...")
            # Columns to keep from advanced (GROUP_ID + unique advanced stats)
            base_cols = set(team_lineup_base.columns)
            adv_cols = set(team_lineup_advanced.columns)
            # Exclude SEASON_TYPE from base_cols for comparison as it's added in both
            base_cols_for_compare = base_cols - {'SEASON_TYPE'}
            adv_unique_cols = list(adv_cols - base_cols_for_compare - {'SEASON_TYPE'}) # Also exclude SEASON_TYPE here
            cols_to_keep = ['GROUP_ID'] + adv_unique_cols
            cols_to_keep = [col for col in cols_to_keep if col in team_lineup_advanced.columns] # Ensure columns exist

            team_lineup_advanced_subset = team_lineup_advanced[cols_to_keep]

            # Perform the merge
            try:
                team_lineup_merged = pd.merge(
                    team_lineup_base, # Already contains SEASON_TYPE
                    team_lineup_advanced_subset,
                    on='GROUP_ID',
                    how='inner', # Keep only lineups present in both Base and Advanced
                    suffixes=('', '_adv') # Suffix for any unexpected overlaps besides GROUP_ID
                )

                if not team_lineup_merged.empty:
                    team_lineup_merged['team'] = team_name
                    team_lineup_merged['team_id'] = team_id_i
                    merged_data_for_season_type = team_lineup_merged # Store merged data
                    print(f"      Successfully merged {len(team_lineup_merged)} {season_type} lineups.")
                else:
                    print(f"      Warning: No common {season_type} lineups found after merging Base and Advanced.")
                    # Decide if you want to keep base-only data in this case
                    # team_lineup_base['team'] = team_name
                    # team_lineup_base['team_id'] = team_id_i
                    # merged_data_for_season_type = team_lineup_base
                    # print("      Using Base stats only for this season type.")


            except KeyError as e:
                 print(f"      Error merging {season_type} data: Missing key {e}. Skipping merge.")
                 # Optionally add base if merge fails due to key error
                 # team_lineup_base['team'] = team_name
                 # team_lineup_base['team_id'] = team_id_i
                 # merged_data_for_season_type = team_lineup_base
                 # print("      Using Base stats only due to merge error.")


        elif team_lineup_base is not None and not team_lineup_base.empty:
             # Handle case where only base stats were retrieved successfully
             print(f"    Warning: Only Base {season_type} stats retrieved or Advanced stats were empty. Using Base stats only.")
             team_lineup_base['team'] = team_name
             team_lineup_base['team_id'] = team_id_i
             # SEASON_TYPE is already in team_lineup_base
             merged_data_for_season_type = team_lineup_base

        # Add similar elif for advanced if needed, though less common to use alone
        # elif team_lineup_advanced is not None and not team_lineup_advanced.empty:
        #      print(f"    Warning: Only Advanced {season_type} stats retrieved. Using Advanced stats only.")
        #      team_lineup_advanced['team'] = team_name
        #      team_lineup_advanced['team_id'] = team_id_i
        #      merged_data_for_season_type = team_lineup_advanced

        else:
            print(f"    No usable {season_type} data retrieved for team {team_name}.")

        # Concatenate the results for this season_type to the main DataFrame
        if merged_data_for_season_type is not None and not merged_data_for_season_type.empty:
            league_lineup = pd.concat([league_lineup, merged_data_for_season_type], ignore_index=True)
            team_has_data = True # Mark that we got some data for this team

        # Small delay between processing season types for the same team (optional but recommended)
        time.sleep(0.5)

    if not team_has_data:
        print(f"  No data added for team {team_name} for either season type.")

    print(f"Finished processing {team_name}. Pausing before next team...")
    time.sleep(1) # Keep delay between different teams

print("-" * 30)
print("All teams processed.")

# In[5]: Post-processing and Saving
print("\nProcessing final DataFrame...")
if not league_lineup.empty:
    # Create player list from GROUP_NAME (handle potential None/NaN in GROUP_NAME)
    league_lineup['players_list'] = league_lineup['GROUP_NAME'].fillna('').str.split(' - ')

    # Sort by team name and then season type for clarity
    league_lineup = league_lineup.sort_values(by=['team', 'SEASON_TYPE', 'MIN'], ascending=[True, True, False]) # Sort by MIN descending within type

    # Save to CSV - update filename to reflect content
    output_filename = f'NBALineup{target_season.replace("-","")}_RegSeason_Playoffs_BaseAdvanced.csv'
    try:
        league_lineup.to_csv(output_filename, index=False)
        print(f"Data saved successfully to {output_filename}")
        print(f"Final DataFrame shape: {league_lineup.shape}")
        print("\nColumns in the final DataFrame:")
        print(league_lineup.columns.tolist()) # Should include 'SEASON_TYPE'
    except Exception as e:
        print(f"Error saving DataFrame to CSV: {e}")

else:
    print("No data was collected. The final DataFrame is empty.")

print("\nScript finished.")
# Out:
# Starting data fetch for season: 2024-25
# ------------------------------
#
# Processing team: Atlanta Hawks (1610612737)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612737 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612737 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612737 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612737 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Atlanta Hawks.
# Finished processing Atlanta Hawks. Pausing before next team...
#
# Processing team: Boston Celtics (1610612738)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612738 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612738 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612738 (Season: 2024-25)...
#       Successfully fetched 22 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612738 (Season: 2024-25)...
#       Successfully fetched 22 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 22 Playoffs lineups.
# Finished processing Boston Celtics. Pausing before next team...
#
# Processing team: Cleveland Cavaliers (1610612739)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612739 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612739 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612739 (Season: 2024-25)...
#       Successfully fetched 27 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612739 (Season: 2024-25)...
#       Successfully fetched 27 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 27 Playoffs lineups.
# Finished processing Cleveland Cavaliers. Pausing before next team...
#
# Processing team: New Orleans Pelicans (1610612740)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612740 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612740 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612740 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612740 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team New Orleans Pelicans.
# Finished processing New Orleans Pelicans. Pausing before next team...
#
# Processing team: Chicago Bulls (1610612741)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612741 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612741 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612741 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612741 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Chicago Bulls.
# Finished processing Chicago Bulls. Pausing before next team...
#
# Processing team: Dallas Mavericks (1610612742)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612742 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612742 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612742 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612742 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Dallas Mavericks.
# Finished processing Dallas Mavericks. Pausing before next team...
#
# Processing team: Denver Nuggets (1610612743)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612743 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612743 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612743 (Season: 2024-25)...
#       Successfully fetched 17 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612743 (Season: 2024-25)...
#       Successfully fetched 17 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 17 Playoffs lineups.
# Finished processing Denver Nuggets. Pausing before next team...
#
# Processing team: Golden State Warriors (1610612744)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612744 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612744 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612744 (Season: 2024-25)...
#       Successfully fetched 30 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612744 (Season: 2024-25)...
#       Successfully fetched 30 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 30 Playoffs lineups.
# Finished processing Golden State Warriors. Pausing before next team...
#
# Processing team: Houston Rockets (1610612745)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612745 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612745 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612745 (Season: 2024-25)...
#       Successfully fetched 21 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612745 (Season: 2024-25)...
#       Successfully fetched 21 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 21 Playoffs lineups.
# Finished processing Houston Rockets. Pausing before next team...
#
# Processing team: Los Angeles Clippers (1610612746)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612746 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612746 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612746 (Season: 2024-25)...
#       Successfully fetched 31 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612746 (Season: 2024-25)...
#       Successfully fetched 31 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 31 Playoffs lineups.
# Finished processing Los Angeles Clippers. Pausing before next team...
#
# Processing team: Los Angeles Lakers (1610612747)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612747 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612747 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612747 (Season: 2024-25)...
#       Successfully fetched 27 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612747 (Season: 2024-25)...
#       Successfully fetched 27 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 27 Playoffs lineups.
# Finished processing Los Angeles Lakers. Pausing before next team...
#
# Processing team: Miami Heat (1610612748)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612748 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612748 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612748 (Season: 2024-25)...
#       Successfully fetched 17 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612748 (Season: 2024-25)...
#       Successfully fetched 17 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 17 Playoffs lineups.
# Finished processing Miami Heat. Pausing before next team...
#
# Processing team: Milwaukee Bucks (1610612749)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612749 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612749 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612749 (Season: 2024-25)...
#       Successfully fetched 25 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612749 (Season: 2024-25)...
#       Successfully fetched 25 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 25 Playoffs lineups.
# Finished processing Milwaukee Bucks. Pausing before next team...
#
# Processing team: Minnesota Timberwolves (1610612750)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612750 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612750 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612750 (Season: 2024-25)...
#       Successfully fetched 28 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612750 (Season: 2024-25)...
#       Successfully fetched 28 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 28 Playoffs lineups.
# Finished processing Minnesota Timberwolves. Pausing before next team...
#
# Processing team: Brooklyn Nets (1610612751)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612751 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612751 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612751 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612751 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Brooklyn Nets.
# Finished processing Brooklyn Nets. Pausing before next team...
#
# Processing team: New York Knicks (1610612752)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612752 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612752 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612752 (Season: 2024-25)...
#       Successfully fetched 27 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612752 (Season: 2024-25)...
#       Successfully fetched 27 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 27 Playoffs lineups.
# Finished processing New York Knicks. Pausing before next team...
#
# Processing team: Orlando Magic (1610612753)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612753 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612753 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612753 (Season: 2024-25)...
#       Successfully fetched 24 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612753 (Season: 2024-25)...
#       Successfully fetched 24 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 24 Playoffs lineups.
# Finished processing Orlando Magic. Pausing before next team...
#
# Processing team: Indiana Pacers (1610612754)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612754 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612754 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612754 (Season: 2024-25)...
#       Successfully fetched 40 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612754 (Season: 2024-25)...
#       Successfully fetched 40 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 40 Playoffs lineups.
# Finished processing Indiana Pacers. Pausing before next team...
#
# Processing team: Philadelphia 76ers (1610612755)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612755 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612755 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612755 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612755 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Philadelphia 76ers.
# Finished processing Philadelphia 76ers. Pausing before next team...
#
# Processing team: Phoenix Suns (1610612756)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612756 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612756 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612756 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612756 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Phoenix Suns.
# Finished processing Phoenix Suns. Pausing before next team...
#
# Processing team: Portland Trail Blazers (1610612757)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612757 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612757 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612757 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612757 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Portland Trail Blazers.
# Finished processing Portland Trail Blazers. Pausing before next team...
#
# Processing team: Sacramento Kings (1610612758)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612758 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612758 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612758 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612758 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Sacramento Kings.
# Finished processing Sacramento Kings. Pausing before next team...
#
# Processing team: San Antonio Spurs (1610612759)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612759 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612759 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612759 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612759 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team San Antonio Spurs.
# Finished processing San Antonio Spurs. Pausing before next team...
#
# Processing team: Oklahoma City Thunder (1610612760)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612760 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612760 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612760 (Season: 2024-25)...
#       Successfully fetched 33 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612760 (Season: 2024-25)...
#       Successfully fetched 33 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 33 Playoffs lineups.
# Finished processing Oklahoma City Thunder. Pausing before next team...
#
# Processing team: Toronto Raptors (1610612761)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612761 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612761 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612761 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612761 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Toronto Raptors.
# Finished processing Toronto Raptors. Pausing before next team...
#
# Processing team: Utah Jazz (1610612762)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612762 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612762 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612762 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612762 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Utah Jazz.
# Finished processing Utah Jazz. Pausing before next team...
#
# Processing team: Memphis Grizzlies (1610612763)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612763 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612763 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612763 (Season: 2024-25)...
#       Successfully fetched 40 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612763 (Season: 2024-25)...
#       Successfully fetched 40 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 40 Playoffs lineups.
# Finished processing Memphis Grizzlies. Pausing before next team...
#
# Processing team: Washington Wizards (1610612764)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612764 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612764 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612764 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612764 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Washington Wizards.
# Finished processing Washington Wizards. Pausing before next team...
#
# Processing team: Detroit Pistons (1610612765)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612765 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612765 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612765 (Season: 2024-25)...
#       Successfully fetched 38 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612765 (Season: 2024-25)...
#       Successfully fetched 38 rows.
#     Merging Base and Advanced Playoffs stats...
#       Successfully merged 38 Playoffs lineups.
# Finished processing Detroit Pistons. Pausing before next team...
#
# Processing team: Charlotte Hornets (1610612766)
#   Processing Regular Season data...
#     Fetching Regular Season - Base stats for team ID 1610612766 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Fetching Regular Season - Advanced stats for team ID 1610612766 (Season: 2024-25)...
#       Successfully fetched 250 rows.
#     Merging Base and Advanced Regular Season stats...
#       Successfully merged 250 Regular Season lineups.
#   Processing Playoffs data...
#     Fetching Playoffs - Base stats for team ID 1610612766 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     Fetching Playoffs - Advanced stats for team ID 1610612766 (Season: 2024-25)...
#       Successfully fetched 0 rows.
#     No usable Playoffs data retrieved for team Charlotte Hornets.
# Finished processing Charlotte Hornets. Pausing before next team...
# ------------------------------
# All teams processed.
#
# Processing final DataFrame...
# Data saved successfully to NBALineup202425_RegSeason_Playoffs_BaseAdvanced.csv
# Final DataFrame shape: (7947, 93)
#
# Columns in the final DataFrame:
# ['GROUP_SET', 'GROUP_ID', 'GROUP_NAME', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'SEASON_TYPE', 'AST_TO', 'TS_PCT_RANK', 'EFG_PCT_RANK', 'POSS', 'E_PACE', 'TM_TOV_PCT_RANK', 'AST_PCT', 'PIE_RANK', 'E_DEF_RATING', 'DREB_PCT', 'NET_RATING_RANK', 'REB_PCT', 'REB_PCT_RANK', 'DEF_RATING', 'NET_RATING', 'E_OFF_RATING', 'PACE_PER40', 'AST_RATIO', 'AST_PCT_RANK', 'DREB_PCT_RANK', 'OREB_PCT', 'EFG_PCT', 'OFF_RATING_RANK', 'PACE_RANK', 'AST_RATIO_RANK', 'AST_TO_RANK', 'PACE', 'DEF_RATING_RANK', 'E_NET_RATING', 'TS_PCT', 'OFF_RATING', 'PIE', 'OREB_PCT_RANK', 'TM_TOV_PCT', 'team', 'team_id', 'players_list']
#
# Script finished.
